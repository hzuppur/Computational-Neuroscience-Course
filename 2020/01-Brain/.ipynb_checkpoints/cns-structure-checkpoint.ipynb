# %% [markdown]
# <h1><center>  Introduction to Computational Neuroscience </center></h1>

# %% [markdown]
# <h1><center> Practice I: Structure of the Brain </center></h1>
# <center>Aqeel Labash, Daniel Majoral, Raul Vicente</center>

# %% [markdown]
# ### Important:
# Make sure that you saved your ipynb file correctly to avoid loss of information. Please submit this **ipynb** file only (unless you have extra files then zip this file with the extra ones). Everything should be included in this file questions, answers, codes, plots, and comments about your solutions.

# %% [markdown]
# My student ID is : <font color='green'>B74792</font> and it took me approximately : <font color='green'> 6 </font> hours to complete the home work.
#
# The data of how long it took you to complete the home work will help us to improve the home works to be balanced.

# %% [markdown]
# ***
# As you might have heard before, structure of the brain is extremely complex. There are lots
# of neurons next to each other, tangled with each other, forming one, almost gap-less mass. In
# pursuit of understanding any complex system, one thing you try to learn is its structure. Once
# you see the structure, you get insights about the purpose of the system. Same, hopefully, stands
# for our brain. Brain structure consist of neurons, their somas (cell bodies), dendrites (input
# channels), axons (output channels) and synapses (connection points).

# %% [markdown]
# ***
# ### Exercice 1: Questionnaire (2 pts)

# %% [markdown]
# **Q1-2:** Does size matter? What is the i) mass and ii) number of neurons in the the brains of the following animals: human, african elephant, horse, giraffe and ant.

# %% [markdown]
# <font color=green>
#     Human brain mass is 1,300-1,400 g. Chudler, Eric H. Brain Facts and Figures. <br/>
#     Human brain has 100 billion neorons. The Science Times Book of the brain. New York: The Lyons Press, 1987. <br/>
#     African elephant brain mass is 4,618.62g https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4053853/ <br/>
#     African elephant brain has 257 billion neorons. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4053853/ <br/>
#     Horse brain mass is  598.63 g. https://www.ncbi.nlm.nih.gov/pubmed/24335261 <br/>
#     Horse brain has 1,200,000,000 neorons .Evolution of the Primate Brain: From Neuron to Behavior <br/>
#     Giraffe brain mass is 753.1g. https://anatomypubs.onlinelibrary.wiley.com/doi/full/10.1002/ar.23593 <br/>
#     Giraffe brain has 107 billion neorons. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4374476/. <br/>
#     Ant brain mass is 1.5mg. https://www.researchgate.net/publication/267892224_Brain_scaling_in_ants_body_to_brain_size_ratio <br/>
#     Ant brain has 250,000 neorons. https://lingolex.com/ants.htm
# </font>

# %% [markdown]
# **Q3:** How many synapses are there in the human brain?

# %% [markdown]
# <font color=green> $10^{14}$ synapses. A Theory of How the Brain Might Work
# Tomaso Poggio</font>

# %% [markdown]
# **Q4:** Compare the bottom-up (biologists) and top-down (engineers, computer scientist) approaches to studying the brain.

# %% [markdown]
# <font color=green>
#     Biologist study the brain by examining brains from different species and performing experiments on them. <br/>
#     Engineers and computer scientists study the brain by simulating neurons and running neural nets.
# </font>

# %% [markdown]
# **Q5:** Scientific study of the brain has many branches. Describe in a few examples what are the following fields studying: i)Developmental Neuroscience
# ii)Clinical Neuroscience
# iii)Computational neuroscience.

# %% [markdown]
# <font color=green>
# Developmental Neuroscience describes the cellular and molecular mechanisms by which complex nervous systems emerge during embryonic development and throughout life.<br/>
#
# Clinical Neuroscience is a branch of neuroscience that focuses on the scientific study of fundamental mechanisms that underlie diseases and disorders of the brain and central nervous system. <br/>
#
# Computational neuroscience is a branch of neuroscience which uses computational approaches, to study the nervous system. Computational approaches include mathematics, statistics, computer simulations, and abstractions.
# </font>

# %% [markdown]
# **Q6:** Why did Golgi think the brain is not comprised of individual cells?

# %% [markdown]
# <font color=green>Golgi thought that the brain is one single continuous network, because when he studied the brain with his black reaction, he saw that everything was closely connected.</font>

# %% [markdown]
# **Q7:** Why did the nervous system evolve (what is the evolutionary advantage it provides)?

# %% [markdown]
# <font color=green>nervous system alows movement</font>

# %% [markdown]
# **Q8:** Name 3 tasks at which computer is much better than human brain and 3 tasks where human brain outperforms any existing computer.

# %% [markdown]
# <font color=green>
#     Computers are better in calculations, analysing larges amounts of data and chess. <br/>
#     Humans are better in complex thinking, image recognition and driving.
# </font>

# %% [markdown]
# **Q9:** Describe the main function of the three main compartments of a neuron: soma, dendrite, axon.

# %% [markdown]
# <font color=green>
#     Soma supports synthetic and metabolic needs. <br/>
#     Dendrites receive information from other neurons. <br/>
#     Axons  conducts information away from cell body.
# </font>

# %% [markdown]
# **Q10:** Name two types of glial cells and their functions?

# %% [markdown]
# <font color=green>
#     Schwann cells are made form myelin sheath in the PNS and speed up axonal transmission <br/>
#     Satellite cells are support clusters of neuron bodies.
# </font>

# %% [markdown]
# **Q11:** What is gray matter and white matter?

# %% [markdown]
# <font color=green>
# Cell bodies and dendrites are called gray matter and axons are called white matter.
# </font>

# %% [markdown]
# **Q12:** The Cerebrum is folded and convoluted to increase the surface area. If you would unfold it,
# how big would it be (surface area)?

# %% [markdown]
# <font color=green>$0.24m^{2}$</font>

# %% [markdown]
# **Q13:** What types of sensors are are there in the skin ?

# %% [markdown]
# <font color=green>Pressure and temperature</font>

# %% [markdown]
# **Q14:** If you were to flick a whale's tail, how long it will take for the signal to reach the whale's brain and some response to come back? How long would it take if there was no myelin around the axons?

# %% [markdown]
# <font color=green>
#     Speed up of transmission in the nervs is: <br/>
#     * myelinated 150 m/s <br/>
#     * unmyelinated 5 m/s <br/><br/>
#     Avarage blue whale is 30 from his head to tail, so the signal would have to travel 60m, so it would take 60/150 = 0.4 s.<br/>
#     If there was no myelin around the axons, the signal would take 60/5 = 12 s. <br/>
# </font>

# %% [markdown]
# **Q15:** What is a neurotransmitter?

# %% [markdown]
# <font color=green>Neurotransmitters are endogenous chemicals that enable neurotransmission. It is a type of chemical messenger which transmits signals across a chemical synapse, such as a neuromuscular junction, from one neuron (nerve cell) to another "target" neuron, muscle cell, or gland cell.</font>

# %% [markdown]
# **Q16:** Describe the sequence of actions (ion channels opening and closing) during the generation of an action potential?

# %% [markdown]
# <font color=green>
#
# 1. Action potential arrives to the axon terminal (pre-synaptic neuron) stimulates the release of packets of neurotransmitters into the synaptic cleft
#
# 2. Neurotransmitters diffuse across the synaptic cleft
#
# 3. Neurotransmitters bind to receptors at the post-synaptic neuron causing ion channels to open
#
# </font>

# %% [markdown]
# ***
# ## Exercise 2: Body mass vs. brain mass (1 pt)

# %% [markdown]
# In the course of evolution as organisms developed additional organs and functions the system
# responsible for controlling these functions had to increase as well. In this exercise we will check
# if it is true that larger animals have larger brain. In the data folder you will find data file
# bodybrain.csv. It has two columns: the first one is the mass of the animal in kilograms, the
# second is the mass of its brain in grams.

# %% [markdown]
# 1) Load the data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib notebook

################################
##### YOUR CODE STARTS HERE ####
#Hint: You can use pandas

df = pd.read_csv("data/bodybrain.csv", header=None, names=["brain_mass", "body_mass"])

##### YOUR CODE ENDS HERE  #####
################################

# %% [markdown]
# 2) Create a scatter plot where body mass is on X axis and brain mass on the Y axis (label
# the axes accordingly.

# %%
################################
##### YOUR CODE STARTS HERE ####

fig, ax = plt.subplots(figsize=(5, 4))

ax.scatter(df["body_mass"], df["brain_mass"])

##### YOUR CODE ENDS HERE  #####
################################
plt.show()

# %% [markdown]
# 3) As you will see the picture is not very interesting, but try plotting in a logarithmic scale
# (use log function).

# %%
################################
##### YOUR CODE STARTS HERE ####

fig, ax = plt.subplots(figsize=(5, 4))

ax.set_xscale("log")
ax.set_yscale("log")

ax.scatter(df["body_mass"], df["brain_mass"])

##### YOUR CODE ENDS HERE  #####
################################
plt.show()

# %% [markdown]
# 4) What is the relation between the two masses?. **Hint:** [log-log-plot](https://en.wikipedia.org/wiki/Log%E2%80%93log_plot)

# %% [markdown]
# <font color=green>Monomial</font>

# %% [markdown]
# ***
# ## Exercise 3: Types of neurons (1.5 pts)

# %% [markdown]
# There are lots of different types of neurons in our nervous system. They have different size,
# structure and function. Let us have a look at some of them:
#
#
# | Pyramidal cell in layer 2 or 3 | Purkinje cell | Spindle neuron | Amacrine cell |
# |---|---|---|---|
# | <img src="imgs/pyramidal2.png" alt="Drawing" style="width: 316px;"/> | <img src="imgs/purkinje.png" alt="Drawing" style="width: 315px;"/> | <img src="imgs/spindle.png" alt="Drawing" style="width: 315px;"/> | <img src="imgs/amacrine.png" alt="Drawing" style="width: 315px;"/> |
#
# | Pyramidal cell in 5 | Basket cell | Sensory neuron |
# |:-:|:-:|:-:|
# | <img src="imgs/pyramidal5.png" alt="Drawing" style="width: 316px;"/> | <img src="imgs/bascet.png" alt="Drawing" style="width: 315px;"/> | <img src="imgs/sensory.png" alt="Drawing" style="width: 315px;"/> |

# %% [markdown]
# In the data folder of this assignment you will find three .swc files. Each file describes reconstructed
# structure of a neuron. A neuron can be characterized by different parameters, such as
# size, bifurcations (branching points), size of soma, etc. In general the task of identifying the
# type of a neuron is quite hard [1](https://www.sciencedirect.com/science/article/pii/S0165017307000768).
#
# Nevertheless, in some cases, different types of neurons have distinguishable shapes. This is what
# we will try to use in this exercise. Your task is to plot neurons from the data files and guess
# which of the above-mentioned types each of them belongs to.

# %% [markdown]
# 1) Have a look inside an .swc file. Each line describes small piece of the neuron (compartment),
# the values in the columns are:
# + ID of the compartment
# + Type of the compartment:
#     - 0 – undefined
#     - 1 – soma
#     - 2 – axon
#     - 3 – basal dendrite
#     - 4 – apical dendrite
# + X coordinate (in m)
# + Y coordinate
# + Z coordinate
# + Radius of the compartment
# + ID of parent compartment (-1 for root compartment)

# %% [markdown]
# 2) Import the 3 coordinates of all compartments.

# %%
################################
##### YOUR CODE STARTS HERE ####

df = pd.read_csv("data/neuron1.swc", header=None, names=["ID", "Type","X", "Y","Z","Radius","Parent_ID"], sep=" ")

##### YOUR CODE ENDS HERE  #####
################################*

# %% [markdown]
# 3) Plot the data in 3D. Hint for matplotlib users:[2](https://matplotlib.org/mpl_examples/mplot3d/scatter3d_demo.py).

# %%
# this allows you to see a 3d plot in the notebook
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D

################################
##### YOUR CODE STARTS HERE ####

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df["X"], df["Y"], df["Z"])

##### YOUR CODE ENDS HERE  #####
################################
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# 4) Look at the resulting 3D image an try to guess type of the neuron

# %% [markdown]
# <font color=green>
#     1. Pyramidal cell in 5<br\>
#     2. Purkinje cell <br\>
#     3. Amacrine cell <br\>
# </font>

# %% [markdown]
# 5)(Optional) If you are not sure about the neuron type based on the scatter plot, feel free to
# draw lines between connected compartments (each compartment is connected to its parent
# compartment, so you need to draw a line segment for each parent-child pair).

# %%
################################
##### YOUR CODE STARTS HERE ####

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(df["X"], df["Y"], df["Z"])


##### YOUR CODE ENDS HERE  #####
################################
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ***
# ## Exercise 4: Brain lesions (1 pt)

# %% [markdown]
# Brain lesions are abnormalities in the structure of the brain, usually due to damage after accidents,
# strokes etc. Some lesions lead to interesting effects, that give us information about the
# functional role of the damaged region - if after damage to some region you cannot see any more,
# then probably that area was crucial for vision.
# Read about brain lesions and their possible consequences.

# %% [markdown]
# Google up one lesion, which has surprising or informative (about function) consequences, and:

# %% [markdown]
# 1) Describe the nature of the lesion, its its characteristics, e.g. is it temporal or permanent, describe the consequences and speculate on how the effect is related to the functional role of that region  (at least 150 word).

# %% [markdown]
# <font color=green>
# Phineas Gage brain lesion
#
# Phineas Gage was injured in a explosion, while working on the railroad. The blast launched a metal rod through his brain's left frontal lobe. Miraculously he survived, but after he recovered from the accident his friends and family noticed that his personality had changed.
#  In the accident large part of his left frontal lobe was damage, as the frontal lobes are considered our emotional control center and home to our personality. The left frontal lobe controls movement related to language. It is specifically the key in movement , all language function, decision making and emotional regulation. After the accident Gage's personality changed a lot. The once mild-mannered worker struggled to stick to even simple plans. He became aggressive in speech and demeanor and had little impulse control. The rod probably damaged the regions of impulse control and personality.
# Phineas Gage's case demonstrates how the brain can adapt to damage and still be functional with a part of it missing.
#
# </font>

# %% [markdown]
# 2) Find a picture of the structure that is damaged, altered or disturbed.

# %% [markdown]
# <font color=green>https://upload.wikimedia.org/wikipedia/commons/1/1b/Simulated_Connectivity_Damage_of_Phineas_Gage_4_vanHorn_PathwaysDamaged.jpg</font>

# %% [markdown]
#  Alternatively, you can describe an interesting transcranial magnetic stimulation (TMS) study.

# %% [markdown]
# <font color=green>Your Answer</font>
